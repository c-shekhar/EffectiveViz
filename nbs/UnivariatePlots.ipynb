# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '../data/'

# %%
pokemon_data = pd.read_csv(path+'pokemon/pokemon.csv')

# %%
pokemon_data.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost      ...       percentage_male  \
# 0             2.0            1.0      ...                  88.1
# ...

# %%
pokemon_data['type1'].value_counts().plot.bar()
# plt.show()

# %%
pokemon_data['hp'].value_counts().sort_index().plot.line()
# plt.show()

# %%
pokemon_data['weight_kg'].plot.hist()
# pokemon_data.loc[pokemon_data['weight_kg']<200]['weight_kg'].plot.hist()
# plt.show()

# %% [markdown]
# #### Plotting with seaborn

# %%
wine_reviews = pd.read_csv(path+'wine-reviews/winemag-data_first150k.csv',index_col=0)

# %%
wine_reviews.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %% [markdown]
# #### Countplot

# %%
sns.countplot(wine_reviews['points'])

# %% [markdown]
# #### Kdeplot

# %%
sns.kdeplot(wine_reviews.loc[wine_reviews['price']<300]['price'])

# %%
wine_reviews.loc[wine_reviews['price'] < 200]['price'].value_counts().sort_index().plot.line()

# %%
len(list(wine_reviews['points'].unique()))
# Out:
# 21

# %%
sns.distplot(wine_reviews['points'],bins=10,kde=False)
